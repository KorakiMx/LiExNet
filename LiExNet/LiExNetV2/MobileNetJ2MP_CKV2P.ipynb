# %%
import os
import cv2
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.applications import MobileNet
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sn

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, regularizers, Input
import tensorflow as tf

# Configurar TensorFlow para usar solo la CPU
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# Define el directorio de la base de datos CK+
directorio = r'C:\Users\Usuario\OneDrive\Desktop\archive'


# Define el mapeo de emociones a etiquetas numéricas basadas en las carpetas
emociones = {
    'anger': 0,
    'contempt': 1,
    'disgust': 2,
    'fear': 3,
    'happy': 4,
    'sadness': 5,
    'surprise': 6
}

# Crear listas para las imágenes y las etiquetas
imagenes_data = []
etiquetas = []

# Recorrer las carpetas de emociones
for emocion, etiqueta in emociones.items():
    carpeta_emocion = os.path.join(directorio, emocion)
    if not os.path.exists(carpeta_emocion):
        continue
    contenido = os.listdir(carpeta_emocion)

    # Cargar imágenes y etiquetas
    for nombre_imagen in contenido:
        ruta_imagen = os.path.join(carpeta_emocion, nombre_imagen)
        if nombre_imagen.endswith(('.png', '.jpg', '.jpeg', '.tiff')):
            imagen_actual = cv2.imread(ruta_imagen, cv2.IMREAD_GRAYSCALE)
            imagen_actual = cv2.resize(imagen_actual, (128, 128))  # Reducir tamaño
            imagen_rgb = cv2.cvtColor(imagen_actual, cv2.COLOR_GRAY2RGB)
            imagen_rgb = imagen_rgb / 255.0  # Normalizar
            imagenes_data.append(imagen_rgb)
            etiquetas.append(etiqueta)

# Convertir listas a arreglos numpy
imagenes_data = np.array(imagenes_data)
etiquetas = np.array(etiquetas)

# Separar los datos en conjuntos de entrenamiento y validación
imagenes_train, imagenes_val, etiquetas_train, etiquetas_val = train_test_split(
    imagenes_data, etiquetas, test_size=0.2, random_state=42
)

# Configurar aumento de datos
datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

# Ajustar el generador al conjunto de entrenamiento
datagen.fit(imagenes_train)

import tensorflow as tf
from tensorflow.keras import layers, models, regularizers


# Definir la entrada
input_shape = (128, 128, 3)

model = models.Sequential()

# Primera capa convolucional con Depthwise separable para mantener eficiencia, con menos filtros
model.add(layers.Conv2D(6, (3, 3), strides=(2, 2), padding='same', activation='relu', input_shape=input_shape))
model.add(layers.BatchNormalization())
model.add(layers.DepthwiseConv2D((3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(12, (1, 1), padding='same', activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# Segunda serie de capas convolucionales, con reducción de filtros
model.add(layers.Conv2D(24, (1, 1), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.DepthwiseConv2D((3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(24, (1, 1), padding='same', activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# Bloque final con menos filtros en las convoluciones
model.add(layers.Conv2D(48, (1, 1), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.DepthwiseConv2D((3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(48, (1, 1), padding='same', activation='relu'))
model.add(layers.GlobalAveragePooling2D())

# Capas densas finales con Dropout ajustado y menor cantidad de unidades
model.add(layers.Dense(24, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(layers.Dropout(0.3))  # Dropout ajustado para reducir sobreajuste
model.add(layers.Dense(7, activation='softmax'))

# Compilación del modelo
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Implementar EarlyStopping y reducción de learning rate en Plateau
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=10)


from sklearn.metrics import f1_score, precision_score, recall_score
import numpy as np
import matplotlib.pyplot as plt

# Definir un callback personalizado para calcular F1, Precision, y Recall
class MetricsCallback(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        self.f1s = []
        self.precisions = []
        self.recalls = []

    def on_epoch_end(self, epoch, logs=None):
        val_predicciones = np.argmax(self.model.predict(self.validation_data[0]), axis=1)
        val_etiquetas = self.validation_data[1]
        
        f1 = f1_score(val_etiquetas, val_predicciones, average='weighted')
        precision = precision_score(val_etiquetas, val_predicciones, average='weighted')
        recall = recall_score(val_etiquetas, val_predicciones, average='weighted')
        
        self.f1s.append(f1)
        self.precisions.append(precision)
        self.recalls.append(recall)
        
        print(f"Epoch {epoch+1} — F1: {f1:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}")
    
    # Sobrescribimos el método set_validation_data para obtener el conjunto de validación
    def set_validation_data(self, validation_data):
        self.validation_data = validation_data

# Instanciar el callback y pasar los datos de validación explícitamente
metrics_callback = MetricsCallback()
metrics_callback.set_validation_data((imagenes_val, etiquetas_val))
# Configurar TensorFlow para usar solo la CPU
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'


# Entrenar el modelo con el callback
history = model.fit(
    imagenes_train, etiquetas_train,
    validation_data=(imagenes_val, etiquetas_val),
    epochs=400,
    batch_size=2,
    callbacks=[metrics_callback]
)

# Graficar F1, Precision y Recall a lo largo de las épocas
epocas = range(1, len(metrics_callback.f1s) + 1)

plt.figure()
plt.plot(epocas, metrics_callback.f1s, label='F1 Score')
plt.plot(epocas, metrics_callback.precisions, label='Precision')
plt.plot(epocas, metrics_callback.recalls, label='Recall')
plt.title('F1, Precision y Recall a lo largo de las épocas')
plt.xlabel('Épocas')
plt.ylabel('Valor')
plt.legend()
plt.show()

# Resumen del modelo
model.summary()

import os
import cv2
import numpy as np
from sklearn.metrics import f1_score, precision_score, recall_score
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# Función para calcular F1, Precision, y Recall
def calcular_metricas(model, imagenes_val, etiquetas_val):
    predicciones = model.predict(imagenes_val)
    predicciones_clases = np.argmax(predicciones, axis=1)
    
    f1 = f1_score(etiquetas_val, predicciones_clases, average='weighted')
    precision = precision_score(etiquetas_val, predicciones_clases, average='weighted')
    recall = recall_score(etiquetas_val, predicciones_clases, average='weighted')
    
    return f1, precision, recall

def calcular_flops(model):
    # Crear una función concreta del modelo
    imagen_de_prueba = tf.random.normal([1, 128, 128, 3])  # Imagen de prueba
    modelo_funcional = tf.function(lambda x: model(x))
    modelo_concreto = modelo_funcional.get_concrete_function(imagen_de_prueba)

    # Convertir el modelo concreto a un gráfico de TensorFlow
    frozen_func = convert_variables_to_constants_v2(modelo_concreto)
    frozen_func.graph.as_graph_def()

    # Utilizar tf.compat.v1.profiler para obtener el número de FLOPS
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()

    # Iniciar el profiler
    flops = tf.compat.v1.profiler.profile(graph=frozen_func.graph, run_meta=run_meta, cmd='scope', options=opts)

    # Devolver los FLOPS
    return flops.total_float_ops  # Esta función devuelve el número total de operaciones de punto flotante


# Función para calcular la huella de memoria
def calcular_memoria_modelo(model):
    # Contar los parámetros del modelo
    total_params = model.count_params()
    
    # Asumiendo que los parámetros están almacenados en float32 (4 bytes por parámetro)
    bytes_por_param = 4
    memoria_total = total_params * bytes_por_param
    
    # Convertir a MB
    memoria_total_mb = memoria_total / (1024 ** 2)
    return memoria_total_mb

# Obtener métricas en el conjunto de validación
f1, precision, recall = calcular_metricas(model, imagenes_val, etiquetas_val)

# Obtener los parámetros del modelo
parametros = model.count_params()

# Extraer Accuracy y Loss de la última época
acc = history.history['accuracy'][-1]
val_acc = history.history['val_accuracy'][-1]
loss = history.history['loss'][-1]
val_loss = history.history['val_loss'][-1]

# Calcular FLOPS y huella de memoria
flops = calcular_flops(model)
memoria_modelo = calcular_memoria_modelo(model)

# Imprimir la tabla con los resultados
print(f"Acc: {acc}, F1: {f1}, P: {precision}, R: {recall}, Loss: {loss}, Parámetros: {parametros}, FLOPS: {flops}, Memoria: {memoria_modelo:.2f} MB")

import pandas as pd

# Crear un diccionario con los resultados de la última época
resultados = {
    'Métrica': ['Accuracy', 'F1 Score', 'Precision', 'Recall', 'Loss', 'Parámetros', 'FLOPS', 'Memoria (MB)'],
    'Valor': [acc, f1, precision, recall, loss, parametros, flops, memoria_modelo]
}

# Convertir el diccionario en un DataFrame de pandas
df_resultados = pd.DataFrame(resultados)

# Guardar la tabla en un archivo Excel
#ruta_excel = r"C:\Users\joshu\OneDrive\Desktop\MNJ2MPCK.xlsx"
#df_resultados.to_excel(ruta_excel, index=False)

# Mostrar el archivo guardado
#ruta_excel
# Graficar las métricas
epocas = range(len(history.history['accuracy']))

# Graficar Accuracy
plt.figure()
plt.plot(epocas, history.history['accuracy'], label='Entrenamiento')
plt.plot(epocas, history.history['val_accuracy'], label='Validación')
plt.title('Accuracy por Época')
plt.xlabel('Época')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Graficar Loss
plt.figure()
plt.plot(epocas, history.history['loss'], label='Entrenamiento')
plt.plot(epocas, history.history['val_loss'], label='Validación')
plt.title('Loss por Época')
plt.xlabel('Época')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Graficar F1, Precision, Recall
metricas = ['F1 Score', 'Precision', 'Recall']
valores = [f1, precision, recall]

plt.figure()
plt.bar(metricas, valores)
plt.title('F1, Precision y Recall en la última época')
plt.ylabel('Valor')
plt.show()


# Realizar predicciones con el modelo
y_pred = model.predict(imagenes_val)
y_pred_clases = np.argmax(y_pred, axis=1)

# Calcular métricas de evaluación
acc_val = accuracy_score(etiquetas_val, y_pred_clases)

# Matriz de confusión de validación
matriz_confusion_val = confusion_matrix(etiquetas_val, y_pred_clases)

# Visualizar la matriz de confusión
ax = sn.heatmap(matriz_confusion_val, annot=True, cmap='Blues')
ax.set_title('Validation data Confusion Matrix')
ax.set_xlabel('Predicted Values')
ax.set_ylabel('Actual Values')

# Ajustar los labels de los ticks
ax.xaxis.set_ticklabels(['NE', 'HA', 'SA', 'SU', 'AN', 'DI', 'FE'])
ax.yaxis.set_ticklabels(['NE', 'HA', 'SA', 'SU', 'AN', 'DI', 'FE'])

plt.show()

# Informe de clasificación
target_names = ['NE', 'HA', 'SA', 'SU', 'AN', 'DI', 'FE']
report = classification_report(etiquetas_val, y_pred_clases, digits=4, target_names=target_names)
print(report)
# Out:
# Epoch 1/400
# 392/392 [==============================] - 10s 3ms/step - loss: 2.3522 - accuracy: 0.1518 - val_loss: 2.2307 - val_accuracy: 0.1218
# Epoch 1 — F1: 0.0343, Precision: 0.1229, Recall: 0.1218
# Epoch 2/400
#  61/392 [===>..........................] - ETA: 0s - loss: 2.2247 - accuracy: 0.1885
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 2.1665 - accuracy: 0.2347 - val_loss: 2.1074 - val_accuracy: 0.2995
# Epoch 2 — F1: 0.1902, Precision: 0.3418, Recall: 0.2995
# Epoch 3/400
#  83/392 [=====>........................] - ETA: 0s - loss: 2.1226 - accuracy: 0.1988
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 2.1144 - accuracy: 0.2372 - val_loss: 2.0572 - val_accuracy: 0.2741
# Epoch 3 — F1: 0.1667, Precision: 0.2485, Recall: 0.2741
# Epoch 4/400
#  64/392 [===>..........................] - ETA: 0s - loss: 2.0695 - accuracy: 0.2812
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 2.0745 - accuracy: 0.2474 - val_loss: 2.0183 - val_accuracy: 0.3350
# Epoch 4 — F1: 0.2354, Precision: 0.3197, Recall: 0.3350
# Epoch 5/400
#  52/392 [==>...........................] - ETA: 1s - loss: 2.0119 - accuracy: 0.3269
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 2.0178 - accuracy: 0.2793 - val_loss: 1.9792 - val_accuracy: 0.3909
# Epoch 5 — F1: 0.2564, Precision: 0.3191, Recall: 0.3909
# Epoch 6/400
#  66/392 [====>.........................] - ETA: 0s - loss: 2.0642 - accuracy: 0.2424
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 2.0379 - accuracy: 0.2679 - val_loss: 1.9575 - val_accuracy: 0.4010
# Epoch 6 — F1: 0.3129, Precision: 0.3168, Recall: 0.4010
# Epoch 7/400
#  88/392 [=====>........................] - ETA: 0s - loss: 2.0231 - accuracy: 0.2614
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.9849 - accuracy: 0.2946 - val_loss: 1.9242 - val_accuracy: 0.3807
# Epoch 7 — F1: 0.2634, Precision: 0.3310, Recall: 0.3807
# Epoch 8/400
#  66/392 [====>.........................] - ETA: 0s - loss: 1.9161 - accuracy: 0.3258
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.9868 - accuracy: 0.2985 - val_loss: 1.8874 - val_accuracy: 0.4264
# Epoch 8 — F1: 0.3245, Precision: 0.2913, Recall: 0.4264
# Epoch 9/400
#  84/392 [=====>........................] - ETA: 0s - loss: 1.9917 - accuracy: 0.2976
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.9619 - accuracy: 0.3278 - val_loss: 1.8636 - val_accuracy: 0.4315
# Epoch 9 — F1: 0.3185, Precision: 0.2996, Recall: 0.4315
# Epoch 10/400
#  80/392 [=====>........................] - ETA: 0s - loss: 1.8920 - accuracy: 0.3625
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.9242 - accuracy: 0.3329 - val_loss: 1.8197 - val_accuracy: 0.4162
# Epoch 10 — F1: 0.3049, Precision: 0.2822, Recall: 0.4162
# Epoch 11/400
#  77/392 [====>.........................] - ETA: 0s - loss: 1.8998 - accuracy: 0.3896
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.9157 - accuracy: 0.3253 - val_loss: 1.8121 - val_accuracy: 0.4162
# Epoch 11 — F1: 0.3277, Precision: 0.2856, Recall: 0.4162
# Epoch 12/400
#  77/392 [====>.........................] - ETA: 0s - loss: 1.9196 - accuracy: 0.3377
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.8926 - accuracy: 0.3469 - val_loss: 1.7788 - val_accuracy: 0.4416
# Epoch 12 — F1: 0.3388, Precision: 0.2977, Recall: 0.4416
# Epoch 13/400
#  74/392 [====>.........................] - ETA: 0s - loss: 1.8245 - accuracy: 0.3986
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.8811 - accuracy: 0.3393 - val_loss: 1.7548 - val_accuracy: 0.4315
# Epoch 13 — F1: 0.3303, Precision: 0.2915, Recall: 0.4315
# Epoch 14/400
#  58/392 [===>..........................] - ETA: 0s - loss: 1.8718 - accuracy: 0.3966
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.8438 - accuracy: 0.3699 - val_loss: 1.7321 - val_accuracy: 0.4365
# Epoch 14 — F1: 0.3442, Precision: 0.3463, Recall: 0.4365
# Epoch 15/400
#  52/392 [==>...........................] - ETA: 1s - loss: 1.8187 - accuracy: 0.3750
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.8182 - accuracy: 0.3827 - val_loss: 1.7004 - val_accuracy: 0.4365
# Epoch 15 — F1: 0.3470, Precision: 0.2992, Recall: 0.4365
# Epoch 16/400
#  81/392 [=====>........................] - ETA: 0s - loss: 1.8303 - accuracy: 0.3580
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.7879 - accuracy: 0.3686 - val_loss: 1.6738 - val_accuracy: 0.4518
# Epoch 16 — F1: 0.3644, Precision: 0.3418, Recall: 0.4518
# Epoch 17/400
#  62/392 [===>..........................] - ETA: 0s - loss: 1.8444 - accuracy: 0.3548
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.7964 - accuracy: 0.3839 - val_loss: 1.6418 - val_accuracy: 0.4365
# Epoch 17 — F1: 0.3309, Precision: 0.3154, Recall: 0.4365
# Epoch 18/400
#  81/392 [=====>........................] - ETA: 0s - loss: 1.7458 - accuracy: 0.4383
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.7852 - accuracy: 0.3801 - val_loss: 1.6228 - val_accuracy: 0.4518
# Epoch 18 — F1: 0.3535, Precision: 0.3147, Recall: 0.4518
# Epoch 19/400
#  78/392 [====>.........................] - ETA: 0s - loss: 1.7524 - accuracy: 0.3718
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.7217 - accuracy: 0.4120 - val_loss: 1.6053 - val_accuracy: 0.4518
# Epoch 19 — F1: 0.3714, Precision: 0.3416, Recall: 0.4518
# Epoch 20/400
#  66/392 [====>.........................] - ETA: 0s - loss: 1.6239 - accuracy: 0.4621
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.7177 - accuracy: 0.3852 - val_loss: 1.6053 - val_accuracy: 0.4975
# Epoch 20 — F1: 0.4353, Precision: 0.3965, Recall: 0.4975
# Epoch 21/400
#  81/392 [=====>........................] - ETA: 0s - loss: 1.6092 - accuracy: 0.4506
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.6722 - accuracy: 0.4388 - val_loss: 1.5556 - val_accuracy: 0.4619
# Epoch 21 — F1: 0.3759, Precision: 0.3420, Recall: 0.4619
# Epoch 22/400
#  62/392 [===>..........................] - ETA: 0s - loss: 1.7215 - accuracy: 0.3871
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.6983 - accuracy: 0.4324 - val_loss: 1.5469 - val_accuracy: 0.4772
# Epoch 22 — F1: 0.3731, Precision: 0.3290, Recall: 0.4772
# Epoch 23/400
#  63/392 [===>..........................] - ETA: 0s - loss: 1.6582 - accuracy: 0.4603
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.6705 - accuracy: 0.4337 - val_loss: 1.5366 - val_accuracy: 0.4670
# Epoch 23 — F1: 0.3755, Precision: 0.3353, Recall: 0.4670
# Epoch 24/400
#  62/392 [===>..........................] - ETA: 0s - loss: 1.5953 - accuracy: 0.4839
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.6486 - accuracy: 0.4362 - val_loss: 1.5147 - val_accuracy: 0.4924
# Epoch 24 — F1: 0.4099, Precision: 0.3685, Recall: 0.4924
# Epoch 25/400
#  91/392 [=====>........................] - ETA: 0s - loss: 1.6892 - accuracy: 0.3681
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.6295 - accuracy: 0.4541 - val_loss: 1.4949 - val_accuracy: 0.4975
# Epoch 25 — F1: 0.4125, Precision: 0.3599, Recall: 0.4975
# Epoch 26/400
#  86/392 [=====>........................] - ETA: 0s - loss: 1.5966 - accuracy: 0.4709
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.6316 - accuracy: 0.4541 - val_loss: 1.4841 - val_accuracy: 0.4873
# Epoch 26 — F1: 0.4006, Precision: 0.3529, Recall: 0.4873
# Epoch 27/400
#  83/392 [=====>........................] - ETA: 0s - loss: 1.5845 - accuracy: 0.4819
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.6120 - accuracy: 0.4592 - val_loss: 1.4609 - val_accuracy: 0.5025
# Epoch 27 — F1: 0.4185, Precision: 0.3764, Recall: 0.5025
# Epoch 28/400
#  85/392 [=====>........................] - ETA: 0s - loss: 1.6683 - accuracy: 0.4824
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.5621 - accuracy: 0.4885 - val_loss: 1.4560 - val_accuracy: 0.4822
# Epoch 28 — F1: 0.4079, Precision: 0.3639, Recall: 0.4822
# Epoch 29/400
#  64/392 [===>..........................] - ETA: 0s - loss: 1.5612 - accuracy: 0.4453
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.5633 - accuracy: 0.4681 - val_loss: 1.4418 - val_accuracy: 0.4924
# Epoch 29 — F1: 0.4167, Precision: 0.3781, Recall: 0.4924
# Epoch 30/400
#  63/392 [===>..........................] - ETA: 0s - loss: 1.5875 - accuracy: 0.4603
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.5524 - accuracy: 0.4770 - val_loss: 1.4140 - val_accuracy: 0.5381
# Epoch 30 — F1: 0.4650, Precision: 0.4154, Recall: 0.5381
# Epoch 31/400
#  83/392 [=====>........................] - ETA: 0s - loss: 1.6101 - accuracy: 0.4699
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.5148 - accuracy: 0.4860 - val_loss: 1.4092 - val_accuracy: 0.5635
# Epoch 31 — F1: 0.4893, Precision: 0.4364, Recall: 0.5635
# Epoch 32/400
#  59/392 [===>..........................] - ETA: 0s - loss: 1.4477 - accuracy: 0.5339
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.5335 - accuracy: 0.4809 - val_loss: 1.3898 - val_accuracy: 0.4975
# Epoch 32 — F1: 0.4225, Precision: 0.3787, Recall: 0.4975
# Epoch 33/400
#  88/392 [=====>........................] - ETA: 0s - loss: 1.4955 - accuracy: 0.4886
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.4856 - accuracy: 0.5089 - val_loss: 1.3663 - val_accuracy: 0.5228
# Epoch 33 — F1: 0.4465, Precision: 0.3962, Recall: 0.5228
# Epoch 34/400
#  62/392 [===>..........................] - ETA: 0s - loss: 1.5142 - accuracy: 0.4758
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.4869 - accuracy: 0.4860 - val_loss: 1.3482 - val_accuracy: 0.5533
# Epoch 34 — F1: 0.4764, Precision: 0.4202, Recall: 0.5533
# Epoch 35/400
#  64/392 [===>..........................] - ETA: 0s - loss: 1.5531 - accuracy: 0.4922
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.4867 - accuracy: 0.4796 - val_loss: 1.3751 - val_accuracy: 0.5482
# Epoch 35 — F1: 0.4585, Precision: 0.4055, Recall: 0.5482
# Epoch 36/400
#  61/392 [===>..........................] - ETA: 0s - loss: 1.5088 - accuracy: 0.5164
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.4511 - accuracy: 0.5255 - val_loss: 1.3380 - val_accuracy: 0.5736
# Epoch 36 — F1: 0.5115, Precision: 0.4680, Recall: 0.5736
# Epoch 37/400
#  66/392 [====>.........................] - ETA: 0s - loss: 1.3961 - accuracy: 0.5152
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.4200 - accuracy: 0.5242 - val_loss: 1.3136 - val_accuracy: 0.5990
# Epoch 37 — F1: 0.5022, Precision: 0.4335, Recall: 0.5990
# Epoch 38/400
#  62/392 [===>..........................] - ETA: 0s - loss: 1.4579 - accuracy: 0.4919
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.4457 - accuracy: 0.5077 - val_loss: 1.3483 - val_accuracy: 0.5685
# Epoch 38 — F1: 0.4953, Precision: 0.4594, Recall: 0.5685
# Epoch 39/400
#  50/392 [==>...........................] - ETA: 1s - loss: 1.4794 - accuracy: 0.5500
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.4426 - accuracy: 0.5204 - val_loss: 1.3106 - val_accuracy: 0.6041
# Epoch 39 — F1: 0.5220, Precision: 0.4642, Recall: 0.6041
# Epoch 40/400
#  62/392 [===>..........................] - ETA: 0s - loss: 1.4067 - accuracy: 0.5081
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.3869 - accuracy: 0.5217 - val_loss: 1.3267 - val_accuracy: 0.5635
# Epoch 40 — F1: 0.4858, Precision: 0.4604, Recall: 0.5635
# Epoch 41/400
#  81/392 [=====>........................] - ETA: 0s - loss: 1.4282 - accuracy: 0.5185
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.3771 - accuracy: 0.5472 - val_loss: 1.2906 - val_accuracy: 0.6041
# Epoch 41 — F1: 0.5500, Precision: 0.5072, Recall: 0.6041
# Epoch 42/400
#  84/392 [=====>........................] - ETA: 0s - loss: 1.4244 - accuracy: 0.5060
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.3845 - accuracy: 0.5434 - val_loss: 1.2841 - val_accuracy: 0.6193
# Epoch 42 — F1: 0.5542, Precision: 0.5034, Recall: 0.6193
# Epoch 43/400
#  66/392 [====>.........................] - ETA: 0s - loss: 1.3726 - accuracy: 0.5227
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.3358 - accuracy: 0.5510 - val_loss: 1.2549 - val_accuracy: 0.5990
# Epoch 43 — F1: 0.5168, Precision: 0.4584, Recall: 0.5990
# Epoch 44/400
#  88/392 [=====>........................] - ETA: 0s - loss: 1.2296 - accuracy: 0.6136
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.3415 - accuracy: 0.5523 - val_loss: 1.2353 - val_accuracy: 0.6345
# Epoch 44 — F1: 0.5547, Precision: 0.4997, Recall: 0.6345
# Epoch 45/400
#  64/392 [===>..........................] - ETA: 0s - loss: 1.2911 - accuracy: 0.5469
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.3354 - accuracy: 0.5357 - val_loss: 1.2212 - val_accuracy: 0.6193
# Epoch 45 — F1: 0.5498, Precision: 0.5035, Recall: 0.6193
# Epoch 46/400
#  62/392 [===>..........................] - ETA: 0s - loss: 1.2883 - accuracy: 0.5806
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.3205 - accuracy: 0.5689 - val_loss: 1.2357 - val_accuracy: 0.6193
# Epoch 46 — F1: 0.5520, Precision: 0.5047, Recall: 0.6193
# Epoch 47/400
#  88/392 [=====>........................] - ETA: 0s - loss: 1.3209 - accuracy: 0.5511
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.3015 - accuracy: 0.5765 - val_loss: 1.1937 - val_accuracy: 0.6294
# Epoch 47 — F1: 0.5591, Precision: 0.5085, Recall: 0.6294
# Epoch 48/400
#  82/392 [=====>........................] - ETA: 0s - loss: 1.3098 - accuracy: 0.5549
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.2854 - accuracy: 0.5689 - val_loss: 1.1792 - val_accuracy: 0.6294
# Epoch 48 — F1: 0.5650, Precision: 0.5145, Recall: 0.6294
# Epoch 49/400
#  63/392 [===>..........................] - ETA: 0s - loss: 1.2138 - accuracy: 0.5714
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.2642 - accuracy: 0.5855 - val_loss: 1.1741 - val_accuracy: 0.6244
# Epoch 49 — F1: 0.5532, Precision: 0.5094, Recall: 0.6244
# Epoch 50/400
#  65/392 [===>..........................] - ETA: 0s - loss: 1.2397 - accuracy: 0.6231
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.2502 - accuracy: 0.5842 - val_loss: 1.1645 - val_accuracy: 0.6142
# Epoch 50 — F1: 0.5458, Precision: 0.4942, Recall: 0.6142
# Epoch 51/400
#  81/392 [=====>........................] - ETA: 0s - loss: 1.2306 - accuracy: 0.6296
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.2715 - accuracy: 0.5906 - val_loss: 1.1709 - val_accuracy: 0.6345
# Epoch 51 — F1: 0.5526, Precision: 0.5065, Recall: 0.6345
# Epoch 52/400
#  83/392 [=====>........................] - ETA: 0s - loss: 1.2497 - accuracy: 0.6145
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.2213 - accuracy: 0.6148 - val_loss: 1.1295 - val_accuracy: 0.6548
# Epoch 52 — F1: 0.5771, Precision: 0.5211, Recall: 0.6548
# Epoch 53/400
#  64/392 [===>..........................] - ETA: 0s - loss: 1.2402 - accuracy: 0.5859
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.2045 - accuracy: 0.5982 - val_loss: 1.1336 - val_accuracy: 0.6396
# Epoch 53 — F1: 0.5806, Precision: 0.5376, Recall: 0.6396
# Epoch 54/400
#  64/392 [===>..........................] - ETA: 0s - loss: 1.2095 - accuracy: 0.6016
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.2133 - accuracy: 0.5906 - val_loss: 1.1035 - val_accuracy: 0.6447
# Epoch 54 — F1: 0.5721, Precision: 0.5233, Recall: 0.6447
# Epoch 55/400
#  65/392 [===>..........................] - ETA: 0s - loss: 1.3639 - accuracy: 0.5077
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.1924 - accuracy: 0.5969 - val_loss: 1.1050 - val_accuracy: 0.6396
# Epoch 55 — F1: 0.5694, Precision: 0.5165, Recall: 0.6396
# Epoch 56/400
#  78/392 [====>.........................] - ETA: 0s - loss: 1.2081 - accuracy: 0.5833
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.1365 - accuracy: 0.6224 - val_loss: 1.0941 - val_accuracy: 0.6548
# Epoch 56 — F1: 0.5709, Precision: 0.5163, Recall: 0.6548
# Epoch 57/400
#  63/392 [===>..........................] - ETA: 0s - loss: 1.1043 - accuracy: 0.6032
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.1494 - accuracy: 0.6097 - val_loss: 1.0516 - val_accuracy: 0.6802
# Epoch 57 — F1: 0.6128, Precision: 0.5590, Recall: 0.6802
# Epoch 58/400
#  82/392 [=====>........................] - ETA: 0s - loss: 1.2314 - accuracy: 0.5976
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.1525 - accuracy: 0.6135 - val_loss: 1.0755 - val_accuracy: 0.6447
# Epoch 58 — F1: 0.5713, Precision: 0.5163, Recall: 0.6447
# Epoch 59/400
#  65/392 [===>..........................] - ETA: 0s - loss: 1.2035 - accuracy: 0.6000
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.1485 - accuracy: 0.6148 - val_loss: 1.0528 - val_accuracy: 0.6701
# Epoch 59 — F1: 0.6034, Precision: 0.6179, Recall: 0.6701
# Epoch 60/400
#  81/392 [=====>........................] - ETA: 0s - loss: 1.0792 - accuracy: 0.6420
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.1371 - accuracy: 0.6301 - val_loss: 1.0327 - val_accuracy: 0.6701
# Epoch 60 — F1: 0.6013, Precision: 0.5496, Recall: 0.6701
# Epoch 61/400
#  61/392 [===>..........................] - ETA: 0s - loss: 1.1839 - accuracy: 0.5820
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.1183 - accuracy: 0.6020 - val_loss: 1.0680 - val_accuracy: 0.6650
# Epoch 61 — F1: 0.5909, Precision: 0.5402, Recall: 0.6650
# Epoch 62/400
#  66/392 [====>.........................] - ETA: 0s - loss: 1.0956 - accuracy: 0.6364
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.1100 - accuracy: 0.6314 - val_loss: 1.0360 - val_accuracy: 0.6751
# Epoch 62 — F1: 0.6155, Precision: 0.5855, Recall: 0.6751
# Epoch 63/400
#  66/392 [====>.........................] - ETA: 0s - loss: 1.1344 - accuracy: 0.5909
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.1076 - accuracy: 0.6263 - val_loss: 1.0682 - val_accuracy: 0.6599
# Epoch 63 — F1: 0.6236, Precision: 0.7012, Recall: 0.6599
# Epoch 64/400
# 392/392 [==============================] - 1s 3ms/step - loss: 1.0709 - accuracy: 0.6556 - val_loss: 1.0091 - val_accuracy: 0.6650
# Epoch 64 — F1: 0.5940, Precision: 0.5402, Recall: 0.6650
# Epoch 65/400
#  62/392 [===>..........................] - ETA: 0s - loss: 1.1347 - accuracy: 0.6532
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.0659 - accuracy: 0.6543 - val_loss: 0.9988 - val_accuracy: 0.6701
# Epoch 65 — F1: 0.5974, Precision: 0.5417, Recall: 0.6701
# Epoch 66/400
#  55/392 [===>..........................] - ETA: 0s - loss: 0.9934 - accuracy: 0.6727
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.0622 - accuracy: 0.6543 - val_loss: 0.9834 - val_accuracy: 0.6802
# Epoch 66 — F1: 0.6096, Precision: 0.5554, Recall: 0.6802
# Epoch 67/400
#  73/392 [====>.........................] - ETA: 0s - loss: 1.0174 - accuracy: 0.6781
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.0461 - accuracy: 0.6607 - val_loss: 1.0281 - val_accuracy: 0.6599
# Epoch 67 — F1: 0.6261, Precision: 0.6276, Recall: 0.6599
# Epoch 68/400
#  80/392 [=====>........................] - ETA: 0s - loss: 1.1043 - accuracy: 0.6500
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.0566 - accuracy: 0.6582 - val_loss: 0.9833 - val_accuracy: 0.6802
# Epoch 68 — F1: 0.6327, Precision: 0.7042, Recall: 0.6802
# Epoch 69/400
# 392/392 [==============================] - 1s 3ms/step - loss: 1.0649 - accuracy: 0.6352 - val_loss: 0.9640 - val_accuracy: 0.6853
# Epoch 69 — F1: 0.6183, Precision: 0.6306, Recall: 0.6853
# Epoch 70/400
#  77/392 [====>.........................] - ETA: 0s - loss: 0.9993 - accuracy: 0.6948
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.0410 - accuracy: 0.6709 - val_loss: 0.9811 - val_accuracy: 0.6904
# Epoch 70 — F1: 0.6328, Precision: 0.6705, Recall: 0.6904
# Epoch 71/400
#  82/392 [=====>........................] - ETA: 0s - loss: 1.0917 - accuracy: 0.6098
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.0434 - accuracy: 0.6403 - val_loss: 0.9614 - val_accuracy: 0.7157
# Epoch 71 — F1: 0.6806, Precision: 0.7492, Recall: 0.7157
# Epoch 72/400
# 392/392 [==============================] - 1s 3ms/step - loss: 1.0079 - accuracy: 0.6735 - val_loss: 1.0207 - val_accuracy: 0.6497
# Epoch 72 — F1: 0.5926, Precision: 0.6138, Recall: 0.6497
# Epoch 73/400
#  59/392 [===>..........................] - ETA: 0s - loss: 1.0996 - accuracy: 0.6186
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 1.0097 - accuracy: 0.6569 - val_loss: 0.9757 - val_accuracy: 0.6853
# Epoch 73 — F1: 0.6295, Precision: 0.6852, Recall: 0.6853
# Epoch 74/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.9833 - accuracy: 0.6747 - val_loss: 0.9272 - val_accuracy: 0.6904
# Epoch 74 — F1: 0.6344, Precision: 0.6086, Recall: 0.6904
# Epoch 75/400
#  73/392 [====>.........................] - ETA: 0s - loss: 0.9340 - accuracy: 0.7055
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 0.9604 - accuracy: 0.6747 - val_loss: 0.9466 - val_accuracy: 0.6954
# Epoch 75 — F1: 0.6412, Precision: 0.7096, Recall: 0.6954
# Epoch 76/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.9779 - accuracy: 0.6747 - val_loss: 0.9468 - val_accuracy: 0.6904
# Epoch 76 — F1: 0.6516, Precision: 0.6309, Recall: 0.6904
# Epoch 77/400
#  56/392 [===>..........................] - ETA: 0s - loss: 1.0857 - accuracy: 0.5893
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 0.9758 - accuracy: 0.6620 - val_loss: 0.9256 - val_accuracy: 0.7005
# Epoch 77 — F1: 0.6624, Precision: 0.6889, Recall: 0.7005
# Epoch 78/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.9337 - accuracy: 0.6913 - val_loss: 0.9151 - val_accuracy: 0.6954
# Epoch 78 — F1: 0.6480, Precision: 0.6165, Recall: 0.6954
# Epoch 79/400
#  84/392 [=====>........................] - ETA: 0s - loss: 0.9686 - accuracy: 0.6548
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 0.9880 - accuracy: 0.6531 - val_loss: 0.9377 - val_accuracy: 0.6904
# Epoch 79 — F1: 0.6447, Precision: 0.7075, Recall: 0.6904
# Epoch 80/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.9394 - accuracy: 0.6952 - val_loss: 0.9088 - val_accuracy: 0.7107
# Epoch 80 — F1: 0.6656, Precision: 0.6320, Recall: 0.7107
# Epoch 81/400
#  80/392 [=====>........................] - ETA: 0s - loss: 1.0291 - accuracy: 0.6500
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 0.9207 - accuracy: 0.7143 - val_loss: 0.8862 - val_accuracy: 0.7107
# Epoch 81 — F1: 0.6795, Precision: 0.6868, Recall: 0.7107
# Epoch 82/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.9320 - accuracy: 0.6926 - val_loss: 0.8852 - val_accuracy: 0.7208
# Epoch 82 — F1: 0.6856, Precision: 0.6934, Recall: 0.7208
# Epoch 83/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.9186 - accuracy: 0.6837 - val_loss: 0.8762 - val_accuracy: 0.7208
# Epoch 83 — F1: 0.6935, Precision: 0.7579, Recall: 0.7208
# Epoch 84/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.9164 - accuracy: 0.6977 - val_loss: 0.8933 - val_accuracy: 0.7056
# Epoch 84 — F1: 0.6752, Precision: 0.7453, Recall: 0.7056
# Epoch 85/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.8884 - accuracy: 0.7219 - val_loss: 0.8664 - val_accuracy: 0.7208
# Epoch 85 — F1: 0.6752, Precision: 0.6463, Recall: 0.7208
# Epoch 86/400
#  60/392 [===>..........................] - ETA: 0s - loss: 0.9942 - accuracy: 0.7000
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 392/392 [==============================] - 1s 3ms/step - loss: 0.9038 - accuracy: 0.7066 - val_loss: 0.9600 - val_accuracy: 0.6904
# Epoch 86 — F1: 0.6633, Precision: 0.6961, Recall: 0.6904
# Epoch 87/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.8836 - accuracy: 0.7066 - val_loss: 0.8575 - val_accuracy: 0.7157
# Epoch 87 — F1: 0.6761, Precision: 0.6497, Recall: 0.7157
# Epoch 88/400
#  60/392 [===>..........................] - ETA: 0s - loss: 0.8341 - accuracy: 0.7333
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
# Epoch 343 — F1: 0.9103, Precision: 0.9210, Recall: 0.9086
# Epoch 344/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2248 - accuracy: 0.9528 - val_loss: 0.4050 - val_accuracy: 0.8883
# Epoch 344 — F1: 0.8905, Precision: 0.9062, Recall: 0.8883
# Epoch 345/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2295 - accuracy: 0.9592 - val_loss: 0.3253 - val_accuracy: 0.8883
# Epoch 345 — F1: 0.8898, Precision: 0.8972, Recall: 0.8883
# Epoch 346/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2537 - accuracy: 0.9464 - val_loss: 0.4785 - val_accuracy: 0.8985
# Epoch 346 — F1: 0.9007, Precision: 0.9094, Recall: 0.8985
# Epoch 347/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2428 - accuracy: 0.9452 - val_loss: 0.3939 - val_accuracy: 0.8680
# Epoch 347 — F1: 0.8706, Precision: 0.8825, Recall: 0.8680
# Epoch 348/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2399 - accuracy: 0.9515 - val_loss: 0.4034 - val_accuracy: 0.8985
# Epoch 348 — F1: 0.8979, Precision: 0.9026, Recall: 0.8985
# Epoch 349/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2359 - accuracy: 0.9490 - val_loss: 0.4270 - val_accuracy: 0.8477
# Epoch 349 — F1: 0.8475, Precision: 0.8611, Recall: 0.8477
# Epoch 350/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2326 - accuracy: 0.9579 - val_loss: 0.3155 - val_accuracy: 0.9086
# Epoch 350 — F1: 0.9074, Precision: 0.9103, Recall: 0.9086
# Epoch 351/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2322 - accuracy: 0.9528 - val_loss: 0.6269 - val_accuracy: 0.8477
# Epoch 351 — F1: 0.8466, Precision: 0.8692, Recall: 0.8477
# Epoch 352/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2491 - accuracy: 0.9452 - val_loss: 0.3862 - val_accuracy: 0.9086
# Epoch 352 — F1: 0.9093, Precision: 0.9169, Recall: 0.9086
# Epoch 353/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2375 - accuracy: 0.9554 - val_loss: 0.3853 - val_accuracy: 0.8883
# Epoch 353 — F1: 0.8899, Precision: 0.8971, Recall: 0.8883
# Epoch 354/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2417 - accuracy: 0.9566 - val_loss: 0.3594 - val_accuracy: 0.9036
# Epoch 354 — F1: 0.9053, Precision: 0.9128, Recall: 0.9036
# Epoch 355/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2481 - accuracy: 0.9490 - val_loss: 0.4650 - val_accuracy: 0.8832
# Epoch 355 — F1: 0.8870, Precision: 0.9002, Recall: 0.8832
# Epoch 356/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2232 - accuracy: 0.9566 - val_loss: 0.3109 - val_accuracy: 0.9239
# Epoch 356 — F1: 0.9239, Precision: 0.9251, Recall: 0.9239
# Epoch 357/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2360 - accuracy: 0.9477 - val_loss: 0.3852 - val_accuracy: 0.8731
# Epoch 357 — F1: 0.8765, Precision: 0.8925, Recall: 0.8731
# Epoch 358/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2192 - accuracy: 0.9554 - val_loss: 0.3284 - val_accuracy: 0.9137
# Epoch 358 — F1: 0.9152, Precision: 0.9186, Recall: 0.9137
# Epoch 359/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2428 - accuracy: 0.9566 - val_loss: 0.3076 - val_accuracy: 0.8985
# Epoch 359 — F1: 0.8996, Precision: 0.9033, Recall: 0.8985
# Epoch 360/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2245 - accuracy: 0.9541 - val_loss: 0.3008 - val_accuracy: 0.9036
# Epoch 360 — F1: 0.9045, Precision: 0.9077, Recall: 0.9036
# Epoch 361/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2423 - accuracy: 0.9452 - val_loss: 0.4004 - val_accuracy: 0.8629
# Epoch 361 — F1: 0.8620, Precision: 0.8664, Recall: 0.8629
# Epoch 362/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2235 - accuracy: 0.9528 - val_loss: 0.3168 - val_accuracy: 0.9086
# Epoch 362 — F1: 0.9091, Precision: 0.9115, Recall: 0.9086
# Epoch 363/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2153 - accuracy: 0.9656 - val_loss: 0.3162 - val_accuracy: 0.9137
# Epoch 363 — F1: 0.9145, Precision: 0.9250, Recall: 0.9137
# Epoch 364/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2165 - accuracy: 0.9617 - val_loss: 0.3130 - val_accuracy: 0.8985
# Epoch 364 — F1: 0.8997, Precision: 0.9041, Recall: 0.8985
# Epoch 365/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2242 - accuracy: 0.9592 - val_loss: 0.4386 - val_accuracy: 0.8782
# Epoch 365 — F1: 0.8793, Precision: 0.8946, Recall: 0.8782
# Epoch 366/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2189 - accuracy: 0.9566 - val_loss: 0.3019 - val_accuracy: 0.8934
# Epoch 366 — F1: 0.8923, Precision: 0.8958, Recall: 0.8934
# Epoch 367/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2183 - accuracy: 0.9643 - val_loss: 0.3074 - val_accuracy: 0.9137
# Epoch 367 — F1: 0.9149, Precision: 0.9185, Recall: 0.9137
# Epoch 368/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2196 - accuracy: 0.9630 - val_loss: 0.3581 - val_accuracy: 0.9086
# Epoch 368 — F1: 0.9096, Precision: 0.9163, Recall: 0.9086
# Epoch 369/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2187 - accuracy: 0.9681 - val_loss: 0.4214 - val_accuracy: 0.9036
# Epoch 369 — F1: 0.9055, Precision: 0.9169, Recall: 0.9036
# Epoch 370/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2220 - accuracy: 0.9592 - val_loss: 0.3189 - val_accuracy: 0.9086
# Epoch 370 — F1: 0.9087, Precision: 0.9125, Recall: 0.9086
# Epoch 371/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2423 - accuracy: 0.9464 - val_loss: 0.2936 - val_accuracy: 0.9239
# Epoch 371 — F1: 0.9241, Precision: 0.9265, Recall: 0.9239
# Epoch 372/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2149 - accuracy: 0.9605 - val_loss: 0.4006 - val_accuracy: 0.8934
# Epoch 372 — F1: 0.8926, Precision: 0.9005, Recall: 0.8934
# Epoch 373/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2316 - accuracy: 0.9605 - val_loss: 0.3159 - val_accuracy: 0.9188
# Epoch 373 — F1: 0.9204, Precision: 0.9258, Recall: 0.9188
# Epoch 374/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2235 - accuracy: 0.9541 - val_loss: 0.4591 - val_accuracy: 0.8629
# Epoch 374 — F1: 0.8639, Precision: 0.8829, Recall: 0.8629
# Epoch 375/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2114 - accuracy: 0.9617 - val_loss: 0.3319 - val_accuracy: 0.9036
# Epoch 375 — F1: 0.9039, Precision: 0.9069, Recall: 0.9036
# Epoch 376/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2145 - accuracy: 0.9668 - val_loss: 0.3665 - val_accuracy: 0.8883
# Epoch 376 — F1: 0.8906, Precision: 0.9020, Recall: 0.8883
# Epoch 377/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2211 - accuracy: 0.9579 - val_loss: 0.3096 - val_accuracy: 0.9289
# Epoch 377 — F1: 0.9304, Precision: 0.9365, Recall: 0.9289
# Epoch 378/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2070 - accuracy: 0.9643 - val_loss: 0.3346 - val_accuracy: 0.9137
# Epoch 378 — F1: 0.9145, Precision: 0.9175, Recall: 0.9137
# Epoch 379/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2404 - accuracy: 0.9375 - val_loss: 0.2968 - val_accuracy: 0.9188
# Epoch 379 — F1: 0.9187, Precision: 0.9208, Recall: 0.9188
# Epoch 380/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2116 - accuracy: 0.9617 - val_loss: 0.3053 - val_accuracy: 0.9086
# Epoch 380 — F1: 0.9068, Precision: 0.9143, Recall: 0.9086
# Epoch 381/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2103 - accuracy: 0.9643 - val_loss: 0.4028 - val_accuracy: 0.8883
# Epoch 381 — F1: 0.8873, Precision: 0.8955, Recall: 0.8883
# Epoch 382/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2293 - accuracy: 0.9490 - val_loss: 0.5409 - val_accuracy: 0.8629
# Epoch 382 — F1: 0.8597, Precision: 0.8689, Recall: 0.8629
# Epoch 383/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2132 - accuracy: 0.9643 - val_loss: 0.2721 - val_accuracy: 0.9289
# Epoch 383 — F1: 0.9289, Precision: 0.9307, Recall: 0.9289
# Epoch 384/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.1993 - accuracy: 0.9643 - val_loss: 0.3541 - val_accuracy: 0.8934
# Epoch 384 — F1: 0.8936, Precision: 0.9030, Recall: 0.8934
# Epoch 385/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.1990 - accuracy: 0.9617 - val_loss: 0.2949 - val_accuracy: 0.9086
# Epoch 385 — F1: 0.9082, Precision: 0.9113, Recall: 0.9086
# Epoch 386/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2257 - accuracy: 0.9566 - val_loss: 0.3135 - val_accuracy: 0.9086
# Epoch 386 — F1: 0.9090, Precision: 0.9143, Recall: 0.9086
# Epoch 387/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2018 - accuracy: 0.9630 - val_loss: 0.3172 - val_accuracy: 0.9036
# Epoch 387 — F1: 0.9046, Precision: 0.9072, Recall: 0.9036
# Epoch 388/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.1974 - accuracy: 0.9605 - val_loss: 0.3180 - val_accuracy: 0.8883
# Epoch 388 — F1: 0.8923, Precision: 0.9012, Recall: 0.8883
# Epoch 389/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2158 - accuracy: 0.9630 - val_loss: 0.2891 - val_accuracy: 0.9036
# Epoch 389 — F1: 0.9050, Precision: 0.9083, Recall: 0.9036
# Epoch 390/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2148 - accuracy: 0.9617 - val_loss: 0.3317 - val_accuracy: 0.9036
# Epoch 390 — F1: 0.9049, Precision: 0.9085, Recall: 0.9036
# Epoch 391/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2137 - accuracy: 0.9605 - val_loss: 0.2981 - val_accuracy: 0.9137
# Epoch 391 — F1: 0.9157, Precision: 0.9217, Recall: 0.9137
# Epoch 392/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2170 - accuracy: 0.9579 - val_loss: 0.3063 - val_accuracy: 0.9036
# Epoch 392 — F1: 0.9036, Precision: 0.9070, Recall: 0.9036
# Epoch 393/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.1872 - accuracy: 0.9745 - val_loss: 0.3935 - val_accuracy: 0.8934
# Epoch 393 — F1: 0.8937, Precision: 0.9023, Recall: 0.8934
# Epoch 394/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2029 - accuracy: 0.9605 - val_loss: 0.3354 - val_accuracy: 0.8883
# Epoch 394 — F1: 0.8876, Precision: 0.8912, Recall: 0.8883
# Epoch 395/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2176 - accuracy: 0.9554 - val_loss: 0.3813 - val_accuracy: 0.8832
# Epoch 395 — F1: 0.8854, Precision: 0.8983, Recall: 0.8832
# Epoch 396/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.1816 - accuracy: 0.9719 - val_loss: 0.3273 - val_accuracy: 0.8985
# Epoch 396 — F1: 0.9008, Precision: 0.9056, Recall: 0.8985
# Epoch 397/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.1971 - accuracy: 0.9643 - val_loss: 0.2925 - val_accuracy: 0.8985
# Epoch 397 — F1: 0.8986, Precision: 0.9002, Recall: 0.8985
# Epoch 398/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2290 - accuracy: 0.9503 - val_loss: 0.3245 - val_accuracy: 0.9036
# Epoch 398 — F1: 0.9030, Precision: 0.9063, Recall: 0.9036
# Epoch 399/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2090 - accuracy: 0.9554 - val_loss: 0.2830 - val_accuracy: 0.9137
# Epoch 399 — F1: 0.9152, Precision: 0.9210, Recall: 0.9137
# Epoch 400/400
# 392/392 [==============================] - 1s 3ms/step - loss: 0.2123 - accuracy: 0.9554 - val_loss: 0.3541 - val_accuracy: 0.8934
# Epoch 400 — F1: 0.8947, Precision: 0.9136, Recall: 0.8934
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 6)         168
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 6)         24
# _________________________________________________________________
# depthwise_conv2d (DepthwiseC (None, 64, 64, 6)         60
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 6)         24
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 12)        84
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 12)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 24)        312
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 24)        96
# _________________________________________________________________
# depthwise_conv2d_1 (Depthwis (None, 32, 32, 24)        240
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 24)        96
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 24)        600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 24)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 48)        1200
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 48)        192
# _________________________________________________________________
# depthwise_conv2d_2 (Depthwis (None, 16, 16, 48)        480
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 48)        192
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 48)        2352
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 48)                0
# _________________________________________________________________
# dense (Dense)                (None, 24)                1176
# _________________________________________________________________
# dropout (Dropout)            (None, 24)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 175
# =================================================================
# Total params: 7,471
# Trainable params: 7,159
# Non-trainable params: 312
# _________________________________________________________________
# WARNING:tensorflow:From c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\tensorflow\python\ops\nn_ops.py:5063: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# Acc: 0.9553571343421936, F1: 0.8946504680440548, P: 0.9136000739055177, R: 0.8934010152284264, Loss: 0.21230940520763397, Parámetros: 7471, FLOPS: 6859410, Memoria: 0.03 MB
#               precision    recall  f1-score   support
#
#           NE     0.9444    0.7391    0.8293        23
#           HA     1.0000    0.6667    0.8000         9
#           SA     0.8750    0.9767    0.9231        43
#           SU     0.9167    0.7333    0.8148        15
#           AN     0.9556    1.0000    0.9773        43
#           DI     0.6207    0.9474    0.7500        19
#           FE     1.0000    0.8667    0.9286        45
#
#     accuracy                         0.8934       197
#    macro avg     0.9018    0.8471    0.8604       197
# weighted avg     0.9136    0.8934    0.8947       197

# %% [markdown]
# VISUALIZACIONES DE PESO Y DATOS ESTADISTICOS

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from scipy.stats import kurtosis, skew

# Modelo original
model_input = model.input
layer_outputs = [layer.output for layer in model.layers]  # Obtenemos las salidas de todas las capas
activation_model = Model(inputs=model_input, outputs=layer_outputs)  # Modelo para activaciones

# Escoge una imagen del conjunto de entrenamiento para visualizar
img = imagenes_train[0]  # Puedes cambiar el índice para seleccionar otras imágenes
img = img.reshape(1, 128, 128, 3)  # Cambia el tamaño según la entrada del modelo

# Obtener las activaciones de todas las capas
activations = activation_model.predict(img)

# Visualizar activaciones para cada capa
images_per_row = 8

for layer_name, layer_activation in zip([layer.name for layer in model.layers], activations):
    print(f"Visualizando activaciones para la capa: {layer_name}")
    
    if len(layer_activation.shape) == 4:  # Si la salida es 4D (batch_size, height, width, channels)
        n_features = layer_activation.shape[-1]  # Número de filtros en la capa
        size = layer_activation.shape[1]  # Tamaño espacial de los mapas de características

        n_cols = n_features // images_per_row  # Número de columnas para organizar los gráficos
        display_grid = np.zeros((size * n_cols, images_per_row * size))

        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0, :, :, col * images_per_row + row]
                channel_image -= channel_image.mean()  # Normalizar para mejorar la visualización
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image

        # Visualizar el grid de activaciones
        scale = 1.0 / size
        plt.figure(figsize=(scale * display_grid.shape[1], scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')
        plt.show()
    
    elif len(layer_activation.shape) == 2:  # Si la salida es 2D (batch_size, features)
        plt.figure(figsize=(10, 4))
        plt.title(f"Activaciones de la capa {layer_name}")
        plt.plot(layer_activation[0])
        plt.show()

    else:
        print(f"No se puede visualizar la activación de la capa {layer_name} de dimensión {len(layer_activation.shape)}")

# Visualización de pesos para todas las capas
for layer in model.layers:
    try:
        pesos, sesgos = layer.get_weights()

        # Número de filtros en la capa
        num_filtros = pesos.shape[-1]

        # Tamaño del grid para visualizar los filtros
        grid_size = int(np.ceil(np.sqrt(num_filtros)))

        # Visualizar los filtros
        fig, axes = plt.subplots(grid_size, grid_size, figsize=(10, 10))
        for i in range(num_filtros):
            filtro = pesos[:, :, 0, i]  # Extrayendo el filtro
            ax = axes[i // grid_size, i % grid_size]
            ax.imshow(filtro, cmap='viridis', aspect='auto')
            ax.axis('off')
        plt.suptitle(f'Pesos de la capa {layer.name}')
        plt.show()
    except:
        # Algunas capas pueden no tener pesos, como MaxPooling2D
        continue

# Cálculo y visualización de estadísticas de pesos para todas las capas
def calcular_entropia(pesos):
    hist, _ = np.histogram(pesos, bins=256, density=True)
    hist += 1e-7  # Evitar log(0)
    return -np.sum(hist * np.log2(hist))

for layer in model.layers:
    try:
        pesos, _ = layer.get_weights()

        # Calcular estadísticas
        media = np.mean(pesos)
        varianza = np.var(pesos)
        asimetria = skew(pesos.flatten())
        curtosis_val = kurtosis(pesos.flatten())
        entropia = calcular_entropia(pesos)
        rango_val = np.ptp(pesos)

        # Mostrar las estadísticas
        print(f"Capa: {layer.name}")
        print(f"  Media: {media}")
        print(f"  Varianza: {varianza}")
        print(f"  Asimetría: {asimetria}")
        print(f"  Curtosis: {curtosis_val}")
        print(f"  Entropía: {entropia}")
        print(f"  Rango: {rango_val}")

        # Graficar la evolución de las estadísticas
        estadisticas = ['Media', 'Varianza', 'Asimetría', 'Curtosis', 'Entropía', 'Rango']
        valores = [media, varianza, asimetria, curtosis_val, entropia, rango_val]

        plt.figure(figsize=(10, 6))
        plt.bar(estadisticas, valores, color='blue')
        plt.title(f'Estadísticas de los Pesos de la Capa {layer.name}')
        plt.ylabel('Valor')
        plt.show()

    except:
        # Algunas capas pueden no tener pesos, como MaxPooling2D
        continue
# Out:
# Visualizando activaciones para la capa: conv2d
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\ipykernel_launcher.py:47: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\matplotlib\tight_bbox.py:71: RuntimeWarning: divide by zero encountered in double_scalars
#   fig.patch.set_bounds(x0 / w1, y0 / h1,
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\matplotlib\tight_bbox.py:72: RuntimeWarning: divide by zero encountered in double_scalars
#   fig.bbox.width / w1, fig.bbox.height / h1)
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\matplotlib\patches.py:750: RuntimeWarning: invalid value encountered in double_scalars
#   y1 = self.convert_yunits(self._y0 + self._height)
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\matplotlib\transforms.py:2053: RuntimeWarning: invalid value encountered in double_scalars
#   self._mtx[1, 2] += ty
# Visualizando activaciones para la capa: batch_normalization
# Visualizando activaciones para la capa: depthwise_conv2d
# Visualizando activaciones para la capa: batch_normalization_1
# Visualizando activaciones para la capa: conv2d_1
# Visualizando activaciones para la capa: max_pooling2d
# Visualizando activaciones para la capa: conv2d_2
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# Visualizando activaciones para la capa: batch_normalization_2
# Visualizando activaciones para la capa: depthwise_conv2d_1
# Visualizando activaciones para la capa: batch_normalization_3
# Visualizando activaciones para la capa: conv2d_3
# Visualizando activaciones para la capa: max_pooling2d_1
# Visualizando activaciones para la capa: conv2d_4
# Visualizando activaciones para la capa: batch_normalization_4
# c:\Users\Usuario\.conda\envs\superduperblop\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# Visualizando activaciones para la capa: depthwise_conv2d_2
# Visualizando activaciones para la capa: batch_normalization_5
# Visualizando activaciones para la capa: conv2d_5
# Visualizando activaciones para la capa: global_average_pooling2d
# Visualizando activaciones para la capa: dense
# Visualizando activaciones para la capa: dropout
# Visualizando activaciones para la capa: dense_1
# Capa: conv2d
#   Media: 0.00871312152594328
#   Varianza: 0.024333182722330093
#   Asimetría: -0.0009102435312533075
#   Curtosis: -1.050804121771517
#   Entropía: -880.5062395495956
#   Rango: 0.6013730764389038
# Capa: depthwise_conv2d
#   Media: -0.0006709042354486883
#   Varianza: 0.027922816574573517
#   Asimetría: 0.056579644134029536
#   Curtosis: -0.7123008760565122
#   Entropía: -1185.9224864924
#   Rango: 0.6613701581954956
# Capa: conv2d_1
#   Media: 0.03870689123868942
#   Varianza: 0.09884706139564514
#   Asimetría: -0.10865274997100942
#   Curtosis: -1.0111458269651494
#   Entropía: -389.9779763606923
#   Rango: 1.1756973266601562
# Capa: conv2d_2
#   Media: 0.0031788793858140707
#   Varianza: 0.058111608028411865
#   Asimetría: -0.016007015352750845
#   Curtosis: -0.8832283828116725
#   Entropía: -167.79112311167182
#   Rango: 1.1601428985595703
# Capa: depthwise_conv2d_1
#   Media: 0.006254213862121105
#   Varianza: 0.011245058849453926
#   Asimetría: -0.19887649800870963
#   Curtosis: -0.5518742636195642
#   Entropía: -947.9409899591085
#   Rango: 0.5426160097122192
# Capa: conv2d_3
#   Media: 0.0026375348679721355
#   Varianza: 0.04525158926844597
#   Asimetría: -0.23758495618856096
#   Curtosis: -0.7734928179795513
#   Entropía: -156.13092296106885
#   Rango: 1.0072689056396484
# Capa: conv2d_4
#   Media: 0.010375174693763256
#   Varianza: 0.029904058203101158
#   Asimetría: 0.038994711580533574
#   Curtosis: -0.3448440589378641
#   Entropía: -146.2484377191281
#   Rango: 1.1234580278396606
# Capa: depthwise_conv2d_2
#   Media: 0.0009302425314672291
#   Varianza: 0.01122334785759449
#   Asimetría: -0.9403761045699487
#   Curtosis: 1.1389674150405185
#   Entropía: -641.7864653980845
#   Rango: 0.6752582788467407
# Capa: conv2d_5
#   Media: -0.027187105268239975
#   Varianza: 0.10826759040355682
#   Asimetría: -0.004531747457949599
#   Curtosis: -0.8993110670467717
#   Entropía: 43.08838995532589
#   Rango: 1.7741023302078247
# Capa: dense
#   Media: 0.0035809034015983343
#   Varianza: 0.006693623028695583
#   Asimetría: 0.1750064795783362
#   Curtosis: 0.3503544844033497
#   Entropía: -1332.5316309713398
#   Rango: 0.5109472274780273
# Capa: dense_1
#   Media: -0.2721358835697174
#   Varianza: 0.7582164406776428
#   Asimetría: -0.885016642306799
#   Curtosis: -0.11237783887903952
#   Entropía: 33.98305777844858
#   Rango: 4.042107582092285

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 6)         168
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 6)         24
# _________________________________________________________________
# depthwise_conv2d (DepthwiseC (None, 64, 64, 6)         60
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 6)         24
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 12)        84
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 12)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 24)        312
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 24)        96
# _________________________________________________________________
# depthwise_conv2d_1 (Depthwis (None, 32, 32, 24)        240
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 24)        96
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 24)        600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 24)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 48)        1200
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 48)        192
# _________________________________________________________________
# depthwise_conv2d_2 (Depthwis (None, 16, 16, 48)        480
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 48)        192
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 48)        2352
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 48)                0
# _________________________________________________________________
# dense (Dense)                (None, 24)                1176
# _________________________________________________________________
# dropout (Dropout)            (None, 24)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 175
# =================================================================
# Total params: 7,471
# Trainable params: 7,159
# Non-trainable params: 312
# _________________________________________________________________

# %%
model.save(r"C:\Users\Usuario\OneDrive\Desktop\Documentos\J2MPV2.h5")
